# %%
import pandas as pd
import numpy as np

animal_df = pd.read_csv("C:\\Users\\Zachary_B\\Desktop\\dataset\\animals_center.csv")
animal_df.head(100)
# Out:
#    animal_id       name                 datetime                monthyear  \
# 0    A845614    A845614  2021-11-13T19:31:00.000  2021-11-13T19:31:00.000
# 1    A845625    A845625  2021-11-13T19:11:00.000  2021-11-13T19:11:00.000
# 2    A845960      *Azul  2021-11-13T18:39:00.000  2021-11-13T18:39:00.000
# 3    A714568     Pierre  2021-11-13T18:38:00.000  2021-11-13T18:38:00.000
# 4    A845983      *Rojo  2021-11-13T18:38:00.000  2021-11-13T18:38:00.000
# ..       ...        ...                      ...                      ...
# 95   A845211        NaN  2021-11-12T13:09:00.000  2021-11-12T13:09:00.000
# 96   A845747   *Begonia  2021-11-12T13:05:00.000  2021-11-12T13:05:00.000
# 97   A846158      Marlo  2021-11-12T13:05:00.000  2021-11-12T13:05:00.000
# 98   A842273      Angel  2021-11-12T13:05:00.000  2021-11-12T13:05:00.000
# 99   A845746  *Hyacinth  2021-11-12T13:05:00.000  2021-11-12T13:05:00.000
#
#               date_of_birth     outcome_type animal_type sex_upon_outcome  \
# ...

# %%
import pandas as pd
import numpy as np
import requests  

url = 'https://data.austintexas.gov//resource/9t4d-g238.json'
response = requests.get(url)
animals = pd.DataFrame(response.json())
animals.head()

animals.to_csv('C:\\Users\\Zachary_B\\Desktop\\dataset\\animal_center.csv', index = False)
animals
# Out:
#     animal_id                 datetime                monthyear  \
# 0     A846641  2021-11-23T10:10:00.000  2021-11-23T10:10:00.000
# 1     A846694  2021-11-23T09:15:00.000  2021-11-23T09:15:00.000
# 2     A846918  2021-11-23T08:46:00.000  2021-11-23T08:46:00.000
# 3     A846275  2021-11-22T18:17:00.000  2021-11-22T18:17:00.000
# 4     A846380  2021-11-22T17:49:00.000  2021-11-22T17:49:00.000
# ..        ...                      ...                      ...
# 995   A844973  2021-10-27T09:36:00.000  2021-10-27T09:36:00.000
# 996   A844981  2021-10-27T09:36:00.000  2021-10-27T09:36:00.000
# 997   A845187  2021-10-27T08:28:00.000  2021-10-27T08:28:00.000
# 998   A845181  2021-10-27T08:27:00.000  2021-10-27T08:27:00.000
# 999   A843134  2021-10-26T19:12:00.000  2021-10-26T19:12:00.000
#
#                date_of_birth outcome_type animal_type sex_upon_outcome  \
# 0    2021-09-21T00:00:00.000     Adoption         Dog    Neutered Male
# ...

# %%
animal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   animal_id         1000 non-null   object
#  1   name              832 non-null    object
#  2   datetime          1000 non-null   object
#  3   monthyear         1000 non-null   object
#  4   date_of_birth     1000 non-null   object
#  5   outcome_type      1000 non-null   object
#  6   animal_type       1000 non-null   object
#  7   sex_upon_outcome  1000 non-null   object
#  8   age_upon_outcome  993 non-null    object
#  9   breed             1000 non-null   object
#  10  color             1000 non-null   object
#  11  outcome_subtype   439 non-null    object
# dtypes: object(12)
# memory usage: 93.9+ KB

# %%
animal_df.describe()
# Out:
#        animal_id  name                 datetime                monthyear  \
# count       1000   832                     1000                     1000
# unique       986   750                      842                      842
# top      A844644  Luna  2021-10-25T09:00:00.000  2021-10-25T09:00:00.000
# freq           2     8                        5                        5
#
#                   date_of_birth outcome_type animal_type sex_upon_outcome  \
# count                      1000         1000        1000             1000
# unique                      476            8           4                5
# top     2021-08-24T00:00:00.000     Adoption         Cat    Neutered Male
# freq                         17          554         477              363
#
#        age_upon_outcome               breed        color outcome_subtype
# count               993                1000         1000             439
# unique               36                 173          109              14
# ...

# %%
animal_df['name'] = animal_df['name'].fillna('unnamed')

# %%
animal_df.isna().sum()
# Out:
# animal_id             0
# name                  0
# datetime              0
# monthyear             0
# date_of_birth         0
# outcome_type          0
# animal_type           0
# sex_upon_outcome      0
# age_upon_outcome      7
# breed                 0
# color                 0
# outcome_subtype     561
# dtype: int64

# %%
animal_df.fillna('no_type_or_subtype', inplace=True)

# %%
animals.isna().sum()
# Out:
# animal_id             0
# datetime              0
# monthyear             0
# date_of_birth         0
# outcome_type          0
# outcome_subtype     581
# animal_type           0
# sex_upon_outcome      0
# age_upon_outcome      0
# breed                 0
# color                 0
# name                165
# dtype: int64

# %% [markdown]
# ### applying and using map and applymap frompandas library

# %%
def divisible_by_5(number):
    
    ...
    ###parameter:an integer
    ###return numbers divisible by 5
    ...
    
    if number% 5 == 0:  
        return True
    else:
        return False
    
    number = [17, 29, 30045, 125]
    list(map(divisible_by_5, numbers))

# %% [markdown]
# ###DataFrame.applymap()

# %%
def long_string(string):


    if len(string) > 10:
        return True
    else:
        return False

# %%
animals_strings = animal_df.applymap(str)
animals_strings.applymap(long_string)
# Out:
#      animal_id   name  datetime  monthyear  date_of_birth  outcome_type  \
# 0        False  False      True       True           True         False
# 1        False  False      True       True           True         False
# 2        False  False      True       True           True         False
# 3        False  False      True       True           True         False
# 4        False  False      True       True           True         False
# ..         ...    ...       ...        ...            ...           ...
# 995      False  False      True       True           True         False
# 996      False  False      True       True           True          True
# 997      False  False      True       True           True         False
# 998      False  False      True       True           True         False
# 999      False  False      True       True           True         False
#
#      animal_type  sex_upon_outcome  age_upon_outcome  breed  color  \
# ...

# %% [markdown]
# ### series.apply()

# %%
animal_df['sex_upon_outcome'].unique()
# Out:
# array(['Neutered Male', 'Spayed Female', 'Intact Male', 'Intact Female',
#        'Unknown'], dtype=object)

# %%
np.unique(animal_df['sex_upon_outcome'], return_counts = True)
# Out:
# (array(['Intact Female', 'Intact Male', 'Neutered Male', 'Spayed Female',
#         'Unknown'], dtype=object),
#  array([146, 133, 363, 312,  46], dtype=int64))

# %%
def  male_or_female(value_from_series):
    
    """
    this is a doctring...
    parameter: a value from the sex_upon_outcome series
    in the Austine Animal Shelter dataset'
    There are five possible values:
    'Spayed Femal', 'Unknown', 'Intact Female', 'Intact Male', 
        'Neutered Male'
        
        Returns:
        female, male, unknoown
        
        """
    if 'female' in value_from_series.lower():
        return 'female'
    
    elif ' male' in value_from_series.lower():
        return 'male'
    
    else:
            return 'unknown'
        
        
animal_df['sex_upon_outcome'].apply(male_or_female)
# Out:
# 0        male
# 1      female
# 2        male
# 3        male
# 4        male
#         ...
# 995      male
# 996      male
# 997    female
# 998    female
# 999      male
# Name: sex_upon_outcome, Length: 1000, dtype: object

# %%
# we can now make a new column, sex:

animal_df['sex'] = animal_df['sex_upon_outcome'].apply(male_or_female)
animal_df.head()
# Out:
#   animal_id     name                 datetime                monthyear  \
# 0   A845614  A845614  2021-11-13T19:31:00.000  2021-11-13T19:31:00.000
# 1   A845625  A845625  2021-11-13T19:11:00.000  2021-11-13T19:11:00.000
# 2   A845960    *Azul  2021-11-13T18:39:00.000  2021-11-13T18:39:00.000
# 3   A714568   Pierre  2021-11-13T18:38:00.000  2021-11-13T18:38:00.000
# 4   A845983    *Rojo  2021-11-13T18:38:00.000  2021-11-13T18:38:00.000
#
#              date_of_birth outcome_type animal_type sex_upon_outcome  \
# 0  2021-08-18T00:00:00.000     Adoption         Cat    Neutered Male
# 1  2021-08-18T00:00:00.000     Adoption         Cat    Spayed Female
# 2  2019-11-07T00:00:00.000     Transfer         Dog      Intact Male
# 3  2013-10-25T00:00:00.000     Transfer         Dog    Neutered Male
# 4  2021-01-08T00:00:00.000     Transfer         Dog      Intact Male
#
#   age_upon_outcome                                   breed         color  \
# ...

# %%
# First, checkout what happens when we split on a space

list(animal_df['age_upon_outcome'].str.split(' '))
# Out:
# [['2', 'months'],
#  ['2', 'months'],
#  ['2', 'years'],
#  ['8', 'years'],
#  ['10', 'months'],
#  ['9', 'months'],
#  ['2', 'years'],
#  ['3', 'years'],
#  ['3', 'months'],
#  ['1', 'year'],
#  ['1', 'year'],
#  ['6', 'years'],
#  ['1', 'year'],
#  ['1', 'year'],
#  ['2', 'years'],
#  ['4', 'years'],
#  ['2', 'years'],
#  ['1', 'year'],
#  ['3', 'years'],
#  ['2', 'years'],
#  ['1', 'year'],
#  ['6', 'years'],
#  ['8', 'months'],
#  ['2', 'years'],
#  ['2', 'months'],
#  ['7', 'years'],
#  nan,
#  nan,
#  nan,
#  ['1', 'year'],
#  ['2', 'months'],
#  ['1', 'year'],
#  ['2', 'months'],
#  ['1', 'month'],
#  ['3', 'months'],
#  ['2', 'months'],
#  ['3', 'years'],
#  ['2', 'years'],
#  ['7', 'months'],
#  ['2', 'years'],
#  ['2', 'years'],
#  ['2', 'months'],
#  ['7', 'months'],
#  ['5', 'years'],
#  ['2', 'months'],
#  ['2', 'months'],
#  ['2', 'months'],
#  ['10', 'years'],
#  ['2', 'months'],
#  ['2', 'months'],
#  ['3', 'years'],
#  ['1', 'month'],
#  ['1', 'year'],
# ...

# %% [markdown]
# ### pair programe 1:

# %% [markdown]
# Take 5 min fill inthr funt below with code that converts age upon outcome to days upon outcome

# %%
#check what values we have for time frame
# unit_values = [age[0] if age[0] =='NULL'
#                else age[1] for age in
#                animals['age_upon_outcome'].str.split(' ')]
 
# set(unit_values)

values = []
for age in animals['age_upon_outcome'].str.split(' '):
    if age[0] == 'NULL':
        values.append(age[0])
    else:
        values.append(age[1])

# %%
animals['days_upon_outcome'] = animals['age_upon_outcome']

# %%
def age_to_days(age):
    
    """
    params: age upon outcome of shelter animal.
    A number followed by a unit of time
    'NULL', 'days', 'months', 'weeks', 'yar', 'years'
    
    returns days old outcome
    """
    
    age_split = age.split(' ')
    
    if len(age_split) == 1:
        return 'NULL'
    
    elif age_split[1] == 'days':
        return age_split[0]
    
    elif age_split[1] == 'month':
        return str(int(age_split[0])*30)
    
    elif age_split[1] == 'year':
        return str(int(age_split[0])*365) + 'days'
    
    else:
        pass
    
animals['days_upon_outcome'] = animals['age_upon_outcome'].map(age_to_days)

animals['days_upon_outcome']
# Out:
# 0         None
# 1         None
# 2      365days
# 3         None
# 4         None
#         ...
# 995       None
# 996    365days
# 997       None
# 998       None
# 999       None
# Name: days_upon_outcome, Length: 1000, dtype: object

# %% [markdown]
# ### Anonymos Function(lambda abstraction)

# %%
# here is an example of a lambda funtion that split off the number from the animal_id.
animals.animal_id.apply(lambda x: x.split('A')[1])
# Out:
# 0      846641
# 1      846694
# 2      846918
# 3      846275
# 4      846380
#         ...
# 995    844973
# 996    844981
# 997    845187
# 998    845181
# 999    843134
# Name: animal_id, Length: 1000, dtype: object

# %% [markdown]
# ### use a lmba function to convert days upon outcome to weeks upon outcome

# %%
np.random.seed(42)

# %% [markdown]
# ### Methods for reorganizingg DataFrames: .groupby()

# %% [markdown]
# The .groupby() is esp usefull for aggregate functions applied to the data grouped in a particular ways

# %%
animals.groupby('animal_type')

# %% [markdown]
# we can groupby  multiple columns, also return a DataFrame groupby object

# %%
animals.groupby(['animal_type', 'outcome_type'])

# %% [markdown]
# ### .groups and .get_group()

# %%
# this returns each group indexed by the group name: I.E. 'Bird', along with the raw indicies of each value
animals.groupby('animal_type').groups
# Out:
# {'Bird': [138, 179, 470, 861, 862, 863, 864, 895], 'Cat': [3, 4, 5, 6, 7, 13, 15, 17, 19, 20, 32, 33, 37, 43, 44, 48, 49, 50, 51, 52, 53, 54, 57, 58, 63, 64, 70, 77, 79, 82, 84, 86, 94, 119, 121, 128, 130, 132, 135, 140, 143, 145, 146, 147, 148, 151, 153, 156, 157, 158, 159, 163, 164, 165, 166, 167, 168, 173, 174, 175, 176, 178, 181, 182, 183, 184, 185, 186, 187, 188, 192, 193, 194, 195, 196, 197, 198, 200, 201, 203, 204, 207, 209, 211, 212, 213, 217, 228, 229, 231, 232, 233, 234, 237, 238, 239, 240, 241, 243, 248, ...], 'Dog': [0, 8, 9, 10, 11, 12, 14, 16, 18, 21, 22, 23, 24, 26, 27, 28, 29, 30, 31, 34, 35, 36, 38, 39, 41, 42, 46, 47, 55, 56, 59, 60, 61, 62, 65, 68, 69, 71, 73, 74, 75, 76, 78, 80, 81, 83, 85, 87, 88, 89, 90, 91, 92, 93, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 120, 122, 123, 124, 125, 126, 127, 129, 131, 133, 134, 136, 137, 139, 141, 142, 149, 150, 152, 154, 155, 160, ...], 'Other': [1, 2, 25,
# ...

# %%
animals.groupby('animal_type').get_group('Cat')
# Out:
#     animal_id                 datetime                monthyear  \
# 3     A846275  2021-11-22T18:17:00.000  2021-11-22T18:17:00.000
# 4     A846380  2021-11-22T17:49:00.000  2021-11-22T17:49:00.000
# 5     A846495  2021-11-22T17:45:00.000  2021-11-22T17:45:00.000
# 6     A846573  2021-11-22T17:38:00.000  2021-11-22T17:38:00.000
# 7     A846572  2021-11-22T17:37:00.000  2021-11-22T17:37:00.000
# ..        ...                      ...                      ...
# 988   A842349  2021-10-27T15:11:00.000  2021-10-27T15:11:00.000
# 989   A842747  2021-10-27T15:09:00.000  2021-10-27T15:09:00.000
# 990   A845041  2021-10-27T13:17:00.000  2021-10-27T13:17:00.000
# 991   A845043  2021-10-27T13:16:00.000  2021-10-27T13:16:00.000
# 993   A842461  2021-10-27T09:50:00.000  2021-10-27T09:50:00.000
#
#                date_of_birth     outcome_type animal_type sex_upon_outcome  \
# 3    2021-07-12T00:00:00.000         Adoption         Cat    Neutered Male
# ...

# %% [markdown]
# ### Groupby method and aggregation

# %%
# same goes for multi index groupbys
animal_outcome = animals.groupby(['animal_type', 'outcome_type'])
animal_outcome.groups
# Out:
# {('Bird', 'Euthanasia'): [179, 470], ('Bird', 'Transfer'): [138, 861, 862, 863, 864, 895], ('Cat', 'Adoption'): [3, 4, 5, 6, 7, 13, 15, 17, 19, 20, 32, 33, 37, 57, 58, 63, 64, 70, 77, 79, 82, 86, 94, 128, 130, 132, 135, 140, 143, 151, 153, 156, 157, 158, 159, 163, 173, 174, 175, 176, 178, 181, 182, 183, 188, 192, 193, 194, 195, 196, 197, 198, 200, 201, 203, 204, 207, 209, 212, 213, 229, 231, 232, 233, 234, 237, 238, 240, 241, 243, 248, 253, 271, 272, 274, 275, 282, 285, 286, 288, 290, 293, 296, 297, 300, 302, 306, 307, 309, 310, 314, 315, 316, 339, 340, 345, 347, 349, 350, 353, ...], ('Cat', 'Died'): [278, 597, 626, 776, 850], ('Cat', 'Euthanasia'): [43, 217, 261, 382, 482, 777, 959], ('Cat', 'Return to Owner'): [119, 121, 211, 239, 273, 276, 410, 737, 896, 922, 990, 991], ('Cat', 'Rto-Adopt'): [228, 971], ('Cat', 'Transfer'): [44, 48, 49, 50, 51, 52, 53, 54, 84, 145, 146, 147, 148, 164, 165, 166, 167, 168, 184, 185, 186, 187, 258, 265, 266, 267, 268, 269, 270, 305, 399, 400, 401, 40
# ...

# %%
# animal_outcome.groups is a dictionary, so you can access the group names using keys()
animal_outcome.groups.keys()
# Out:
# dict_keys([('Bird', 'Euthanasia'), ('Bird', 'Transfer'), ('Cat', 'Adoption'), ('Cat', 'Died'), ('Cat', 'Euthanasia'), ('Cat', 'Return to Owner'), ('Cat', 'Rto-Adopt'), ('Cat', 'Transfer'), ('Dog', 'Adoption'), ('Dog', 'Died'), ('Dog', 'Euthanasia'), ('Dog', 'Missing'), ('Dog', 'Return to Owner'), ('Dog', 'Rto-Adopt'), ('Dog', 'Transfer'), ('Other', 'Adoption'), ('Other', 'Disposal'), ('Other', 'Euthanasia'), ('Other', 'Transfer')])

# %%
# we can get a specofic group, such as Cats that were adopted
animal_outcome.get_group(('Cat', 'Adoption'))
# Out:
#     animal_id                 datetime                monthyear  \
# 3     A846275  2021-11-22T18:17:00.000  2021-11-22T18:17:00.000
# 4     A846380  2021-11-22T17:49:00.000  2021-11-22T17:49:00.000
# 5     A846495  2021-11-22T17:45:00.000  2021-11-22T17:45:00.000
# 6     A846573  2021-11-22T17:38:00.000  2021-11-22T17:38:00.000
# 7     A846572  2021-11-22T17:37:00.000  2021-11-22T17:37:00.000
# ..        ...                      ...                      ...
# 985   A844800  2021-10-27T16:24:00.000  2021-10-27T16:24:00.000
# 986   A844665  2021-10-27T16:12:00.000  2021-10-27T16:12:00.000
# 988   A842349  2021-10-27T15:11:00.000  2021-10-27T15:11:00.000
# 989   A842747  2021-10-27T15:09:00.000  2021-10-27T15:09:00.000
# 993   A842461  2021-10-27T09:50:00.000  2021-10-27T09:50:00.000
#
#                date_of_birth outcome_type animal_type sex_upon_outcome  \
# 3    2021-07-12T00:00:00.000     Adoption         Cat    Neutered Male
# ...

# %%
# other methods
animal_outcome.first()
# Out:
#                             animal_id                 datetime  \
# animal_type outcome_type
# Bird        Euthanasia        A846328  2021-11-17T09:54:00.000
#             Transfer          A845661  2021-11-18T14:00:00.000
# Cat         Adoption          A846275  2021-11-22T18:17:00.000
#             Died              A762152  2021-11-15T10:00:00.000
#             Euthanasia        A846807  2021-11-21T11:14:00.000
#             Return to Owner   A846248  2021-11-19T11:36:00.000
#             Rto-Adopt         A846225  2021-11-15T18:25:00.000
#             Transfer          A846811  2021-11-21T11:09:00.000
# Dog         Adoption          A846641  2021-11-23T10:10:00.000
#             Died              A846593  2021-11-21T00:00:00.000
#             Euthanasia        A846379  2021-11-21T15:52:00.000
#             Missing           A831773  2021-11-10T10:33:00.000
#             Return to Owner   A846820  2021-11-22T14:12:00.000
# ...

# %%
animal_outcome.last()
# Out:
#                             animal_id                 datetime  \
# animal_type outcome_type
# Bird        Euthanasia        A846121  2021-11-10T10:07:00.000
#             Transfer          A842878  2021-10-30T15:07:00.000
# Cat         Adoption          A842461  2021-10-27T09:50:00.000
#             Died              A845350  2021-11-01T09:12:00.000
#             Euthanasia        A844992  2021-10-28T10:18:00.000
#             Return to Owner   A845043  2021-10-27T13:16:00.000
#             Rto-Adopt         A844359  2021-10-27T17:47:00.000
#             Transfer          A845265  2021-10-27T16:00:00.000
# Dog         Adoption          A843134  2021-10-26T19:12:00.000
#             Died              A844914  2021-10-27T16:31:00.000
#             Euthanasia        A845022  2021-10-28T10:19:00.000
#             Missing           A831773  2021-11-10T10:33:00.000
#             Return to Owner   A845179  2021-10-27T12:45:00.000
# ...

# %%
animal.groupby('animal_type').mean()[animals['animal_type']['Dog']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-9a38692d4b1b> in <module>
# ----> 1 animal.groupby('animal_type').mean()[animals['animal_type']['Dog']]
#
# NameError: name 'animal' is not defined

# %%
# Group by multiple indices
animals.groupby(['animal_type', 'outcome_type',]).get_group(('Cat', 'Transfer')).describe()
# Out:
#        animal_id                 datetime                monthyear  \
# count        116                      116                      116
# unique       116                       69                       69
# top      A845460  2021-11-06T13:18:00.000  2021-11-06T13:18:00.000
# freq           1                        4                        4
#
#                   date_of_birth outcome_type animal_type sex_upon_outcome  \
# count                       116          116         116              116
# unique                       61            1           1                5
# top     2021-10-25T00:00:00.000     Transfer         Cat    Intact Female
# freq                          8          116         116               54
#
#        age_upon_outcome               breed  color outcome_subtype    name  \
# count               116                 116    116             116      67
# unique               23                   5     28               2      66
# ...
