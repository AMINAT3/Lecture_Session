# %% [markdown]
# Adding to Data Frame

# %%
import pandas as pd

# %%
extra_rows = {'age': [40, 30], 'sex': [1, 0], 'cp': [0, 0], 'trestbps': [120, 130],
            'chol': [240, 200],
            'fbs': [0, 0], 'restecg': [1, 0], 'thalach': [120, 122,],'exang': [0, 1],
            'olapeak': [0.1, 1.0], 'slope': [1, 1], 'ca': [0, 1], 'thal': [2, 3],
            'target': [0, 0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'thalach': [120, 122],
#  'exang': [0, 1],
#  'olapeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %% [markdown]
# how to add bottom to dataset

# %%
extras = pd.DataFrame().from_dict(extra_rows)

extras
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  olapeak  slope  \
# 0   40    1   0       120   240    0        1      120      0      0.1      1
# 1   30    0   0       130   200    0        0      122      1      1.0      1
#
#    ca  thal  target
# 0   0     2       0
# 1   1     3       0

# %% [markdown]
# concatenate two dataframe together

# %%
heart = pd.read_csv("C:\\Users\\BADIRU\\Downloads\\heart.csv")
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_augmented = pd.concat([heart, extras], ignore_index = True)

# %% [markdown]
# check to make sure its successful

# %%
heart_augmented.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      NaN
# 304   30    0   0       130   200    0        0      122      1      NaN
#
#      slope  ca  thal  target  olapeak
# 300      1   2     3       0      NaN
# 301      1   1     3       0      NaN
# 302      1   1     2       0      NaN
# 303      1   0     2       0      0.1
# 304      1   1     3       0      1.0

# %%
# .value_counts()

heart_augmented['slope'].value_counts()
# Out:
# 1    142
# 2    142
# 0     21
# Name: slope, dtype: int64

# %%
heart['test'] = 0

heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  test
# 0        0   0     1       1     0
# ...

# %%
heart['twice age'] = heart['age']*2
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  test  twice age
# ...

# %%
heart[heart['age'] >= 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target  test  twice age
# 25       2   2     2       1     0        142
# 60       2   1     2       1     0        142
# ...

# %%
heart.loc[:9, ['age', 'trestbps']]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %%
heart.loc[:7, ['sex', 'fbs', 'slope']]
# Out:
#    sex  fbs  slope
# 0    1    1      0
# 1    1    0      0
# 2    0    0      2
# 3    1    0      2
# 4    0    0      2
# 5    1    0      1
# 6    0    0      1
# 7    1    0      2

# %%
score = (">= 0.9, >= 0.8, >= 0.7, >= 0.6, < 0.6")
a = (0.7)
if 0.0 < a > 1.0:
    print(" sore of out of range")
    
elif a >= 0.9:
        print("A")
elif a >= 0.8:
            print(B)
elif a >= 0.7:
                print("C")
elif a >= 0.6:
                    print("D")
elif a < 0.6:
                        print("F")
# Out:
# C
